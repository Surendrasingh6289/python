# %%
# 1768. Merge Strings Alternately

word1 = 'abc'
word2 = 'pqr'
merge = ''
for i in word1:
    for j in word2:
        merge+=i+j
print(merge)
# Out:
# apaqarbpbqbrcpcqcr

# %%
s = "a"
t = "aa"

for i in t:
    if i not in s:
        print(i)
