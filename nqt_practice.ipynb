# %%
li = [1,2,3,67,988,2,34,56,0,8,54]
min = li[0]
for i in range(len(li)):
    if li[i]<min:
        min = li[i]
print(min)
# Out:
# 1

# %%
li = [1,2,3,67,988,2,34,56,0,8,54]
max = li[0]
for i in range(len(li)):
    if li[i]>max:
        max = li[i]
print(max)
# Out:
# 988

# %%
li = [1,2,3,67,988,2,34,56,0,8,54]
min_value = li[0]

for i in range(len(li)):
    for j in range(i,len(li)):
        if li[i]>li[j]:
            li[i],li[j] = li[j],li[i]
print('second smallest: ',li[1])
print("second largest: ",li[-2])
# Out:
# second smallest:  1
# second largest:  67

# %%
li = [1,2,3,67,988,2,34,56,0,8,54]
reverse_li: list = []
for i in range(len(li)-1,-1,-1):
    reverse_li.append(li[i])
print(reverse_li)
# Out:
# [54, 8, 0, 56, 34, 2, 988, 67, 3, 2, 1]

# %%
li = [1,2,3,67,988,2,34,56,0,8,54]
n= len(li)
left = 0
right = n-1
while left < right :
    li[left],li[right]=li[right],li[left]
    left+=1
    right-=1
print(li)
# Out:
# [54, 8, 0, 56, 34, 2, 988, 67, 3, 2, 1]
