# %%
file = open("Surendra.txt",'w')
file.write("hello! learning file handling.")
file.close()

# %%
aj = open("ajit.txt",'r+')
aj.write('RIP nigga')
aj.close()

# %%
aj = open("ajit.txt",'a')
aj.write("""In the tapestry of Maharashtra’s political landscape, Shri Ajit Dada Pawar emerges as a beacon of dedication and profound empathy. With the grace of a statesman and the tireless devotion of a leader, he dedicates an astounding 16-17 hours each day to the noble cause of uplifting his people and alleviating their concerns.
The visionary leadership of Shri Ajit Pawar has woven an enduring legacy over three decades into the governance and society of Maharashtra.
Admired for his punctuality and unwavering commitment to progress, he emerges as the force behind a revolutionary journey that leads to a “New Maharashtra.”
Under his leadership, Maharashtra reaches out to previously unheard levels of development and prosperity as it confidently moves forward.""")
aj.close()

# %%
with open("ajit.txt",'w') as file:
    file.write("""Well-known for his openness and steadfast attitude, he tackles problems from a practical but sympathetic perspective from the busy streets of Mumbai to the peaceful villages tucked away in the countryside, Shri Ajit Pawar’s resolute dedication to the welfare of every individual exemplifies inclusivity and empathy.""")
