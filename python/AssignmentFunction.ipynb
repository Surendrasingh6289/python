# %%
def kw_fun(**kwargs):
    for i,j in kw_fun.items():
        print(i,j)
kw_fun(name = 'surendra',age = 22)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       2     for i,j in kw_fun.items():
#       3         print(i,j)
# ----> 4 kw_fun(name = 'surendra',age = '22')
#
# Cell In[2], line 2, in kw_fun(**kwargs)
#       1 def kw_fun(**kwargs):
# ----> 2     for i,j in kw_fun.items():
#       3         print(i,j)
#
# AttributeError: 'function' object has no attribute 'items'
