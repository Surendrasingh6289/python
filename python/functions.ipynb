# %%
def Add(a,b,c):
    sum = a+b+c
    return sum
Add(1,2,3)
Add(5,6,2)
Add(5,10,7)
# Out:
# 22

# %%
def Add(a=10,b=20,c=30):
    sum= a+b+c
    return sum
Add(10,23,13)
Add()
# Out:
# 60

# %%
def add(*mun):
    print(type(mun))
add()
# Out:
# <class 'tuple'>

# %%
def fact(n):
    if n >=1:
        return n*fact(n-1)
    else:
        return 1

fact(10)
# Out:
# 3628800

# %%
def Sum(x):
    if x>0:
        return x+Sum(x-1)
    else:
        return 0
Sum(0)
# Out:
# 0
