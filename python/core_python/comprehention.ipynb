# %%
l = 'google'
list_comp = [i for i in l]
list_comp
# Out:
# ['g', 'o', 'o', 'g', 'l', 'e']

# %%
l1 = [ 'atul','betul']
new_l1 = [i.upper() for i in l1]
new_l1
# Out:
# ['ATUL', 'BETUL']

# %%
l2 = ['machine',1,3,6,5,35,87,54.86,'learning']
l3 = [i for i in l2  if type(i)==str]
l4 = [i for i in l2 if type(i)==int]
l5 = [i for i in l2 if type(i)==float]
print(l3,l4,l5)
# Out:
# ['machine', 'learning'] [1, 3, 6, 5, 35, 87] [54.86]
