# %%
x = set()
type(x)
len(x)
# Out:
# 0

# %%
y = {24,5,65,87,23,658,322,2,2,23,'surendra',True,False}
len(y)
print(y)
# Out:
# {0, 65, 322, 2, True, 5, 658, 'surendra', 23, 87, 24}

# %%
for i in y:
    print(i)
# Out:
# 0
# 65
# 322
# 2
# 5
# 658
# 23
# 87
# 24

# %%
a = {1,2,3,4}
b = {2,3,8,7}
