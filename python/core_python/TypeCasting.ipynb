# %%
a = input("Enter Your Value: ")
print(a)
print(type(a))
# Out:
# 23
# <class 'str'>

# %%
y =  int (input("Enter Your values: "))
print(y)
print(type(y))
# Out:
# 5637
# <class 'int'>

# %%
y = float(input("Enter Your values: "))
print(y)
print(type(y))
# Out:
# 50.123
# <class 'float'>

# %%
y = complex(input("Enter Your values: "))
print(y)
print(type(y))
# Out:
# (3+2j)
# <class 'complex'>

# %%
X = 64923
Y = 97239
div = X/Y
print(div)
# Out:
# 0.667664208805109

# %%
X = 64923
Y = 97
div = X/Y
print(int(div))
# Out:
# 669

# %%
x = 67
print(x)
print(type(x))
y = str(x)
print(y)
print(type(y))
# Out:
# 67
# <class 'int'>
# 67
# <class 'str'>

# %%
u = "java"
print(u)
print(type(u))
v = int(u)
print(u)
print(type(v))
# Out:
# java
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 print(u)
#       3 print(type(u))
# ----> 4 v = int(u)
#       5 print(u)
#       6 print(type(v))
#
# ValueError: invalid literal for int() with base 10: 'java'
