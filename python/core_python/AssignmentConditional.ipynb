# %%
#Check if a given number is positive

num = int(input("Enter a num: "))

if num > 0 :
    print("Positive number")
elif num < 0:
    print("Negative number")
# Out:
# Negative number

# %%
#Check if a given number is even.

x = int(input("Enter values: "))

if x % 2 ==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
#Check if a given number is a multiple of 5.

x = int(input("Enter values: "))

if x % 5 ==0:
    print(x," is a Multiple of 5")
else:
    print(x," is Not a multiple of 5")
# Out:
# Not a multiple of 5

# %%
#Check if a given string is empty.
s = ""

if len(s)==0:
    print("Empty string")
else:
    print("Not Empty string")
# Out:
# Empty string

# %%
#Check if a given year is a leap year.

x = int(input("Enter year: "))

if (x % 4==0 and x % 100 !=0) or (x % 400 == 0):
    print("Leap year",x)
else:
    print("Not leap year",x)

# %%
#Check if a given character is a vowel.

x = input()

if x =='a' or x=='i' or x=='e' or x=='u' or x=='o':
    print("Vowel")
else:
    print("Consonant")

# %%
#Check if a given number is between 1 and 10 (inclusive).

x = int(input("Enter a value between 1-10: "))
if x >=1 and x <=10:
    print("Number is b/w 1-10")
else:
    print("Number is not between 1-10")
# Out:
# Number is not between 1-10

# %%
#Check if a given string is a palindrome.

s = input()

if s[0::]==s[::-1]:
    print("palindrome")
else:
    print("Not palindrome")
# Out:
# palindrome

# %%
#Check if a given number is a prime number.

x = int(input("Enter value: "))

if x <= 1:
    print("not prime")
else:
    for i in range(2,int(x**0.5)+1):
        if x % i == 0:
            print("not prime")
            break
    else :
        print("prime")
# Out:
# not prime

# %%
#Check if a given string is a pangram.
sentence = input("Enter your sentence: ").lower()
alphabet = 'qwertyuiopasdfghjklzxcvbnm'

for i in alphabet:
    if i not in sentence:
        print("Not pangram")
        break
else:
    print("pangram")
# Out:
# pangram

# %%
#Check if a given list is empty.
a = []

if len(a) == 0:
    print("Empty list")
else:
    print("not empty list")
# Out:
# Empty list

# %%
#Check if a given number is divisible by both 2 and 3.
num = int(input())

if num % 2 == 0 and num % 2 == 0:
    print("divisible by both 2 and 3")
else :
    print("not divisible by both 2 and 3")

# %%
# Check if a given string contains only digits.
n = input("Enter value: ")

if n.isdigit() == True:
    print("Only digits")
else:
    print("Not Only Digits")
# Out:
# Not Only Digits

# %%
#Check if a given number is a perfect square.
n = int(input("Enter number: "))
root = int(n ** 0.5)
if n < 0:
    print("not a perfect square")
else:
    if  root * root == n:
        print("perfect square")
    else :
        print("not a perfect square")
# Out:
# not a perfect square

# %%
#Check if a given string starts with a capital letter.

s = input("Enter a string: ")

if s and s[0].isupper():
    print("first letter is capital")
else:
    print("not capital")
# Out:
# not capital

# %%
#Check if a given list contains a specific element.

lis = [1,2,3,4,5]
n = int(input("Enter value: "))

if n in lis:
    print("is in list")
else:
    print("not in list")
# Out:
# not in list

# %%
#Check if a given number is negative or zero.
n = int(input("Enter a value: "))

if n <=0:
    print("number is negative or zero")
else:
    print("number is positive")
# Out:
# number is negative or zero

# %%
#Check if a given string is alphanumeric.

n = input("enter a string: ")
a = n.isalnum()
if a == True:
    print("Alphanumeric")
else :
    print("Not alphanumeric")
# Out:
# Not alphanumeric

# %%
#Check if a given year is a leap year and divisible by 100.

year = int(input())
if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    if year % 100 == 0:
        print("leap year and divisible by 100")
    else:
        print("leap year but not divisible by 100")
else :
    print("not a leap year")
# Out:
# leap year but not divisible by 100

# %%
 #Check if a given list is sorted in ascending order.

list1 = [45,67,23,12,78,11]
#list1 = [1,2,3,4,5]
list2 = sorted(list1)
if list1 == list2 :
    print("list is sorted")
else:
    print("not sorted")
# Out:
# not sorted

# %%
#Check if a given year is a leap year or divisible by 400.
year = int(input("Enter year: "))
if year % 4 == 0 and year % 100 != 0 or year % 400==0:
    if year % 400==0:
        print("leap year and divisible by 400.")
    else:
        print("leap year but not divisible by 400.")
else :
    print("not leap year")
# Out:
# not leap year

# %%
#Check if a given string contains only uppercase letters.

s = input()
if s.isupper() ==True:
    print("contains only uppercase")
else:
    print("does not contain only uppercase")
# Out:
# True

# %%
#Check if a given number is a multiple of both 3 and 4.

n = int(input())

if n % 3 ==0  and n %4 ==0:
    print("is divisible by both 3 and 4")
else: 
    print("not divisible by 3 and 4")
# Out:
# is divisible by both 3 and 4

# %%
#Check if a given string contains only lowercase letters.

s = input()
if s.islower()==True:
    print("string is lowercase")
else:
    print("string is  not lowercase")
# Out:
# string is lowercase

# %%
#Check if a given number is divisible by either 5 or 7.

n = int(input("Enter value: "))
if n % 5 ==0 or n% 7 ==0:
    print("divisible by  5 or 7")
else:
    print("not divisible by  5 or 7")
# Out:
# divisible by  5 or 7

# %%
#Check if a given number is a multiple of 10 and less than 100.

n = int(input())

if n % 10 ==0 and n< 100:
    print("multiple of 10 and less than 100")
else:
    print("not a multiple of 10 or less than 100")
# Out:
# not a multiple of 10 or less than 100

# %%
#Check if a given number is divisible by 2, 3, and 5.
n = int(input())
if n % 2 ==0 and n%3==0  and n%5 ==0:
    print("divisible by 2, 3, and 5")
else:
    print("not divisible by 2, 3, and 5")
# Out:
# not divisible by 2, 3, and 5

# %%
#Check if a given number is a multiple of 4 and not divisible by 6
n = int(input("Enter value:"))

if n%4==0 and n%6!=0:
    print("multiple of 4 and not divisible by 6")
else:
    print("not a multiple of 4 or is divisble by 6")
# Out:
# multiple of 4 and not divisible by 6

# %%
#Check if a given number is divisible by the sum of its digits

n =input("Enter  values: ")
sum = 0
for i in n:
    i= int(i)
    sum +=i
if int(n)%sum == 0:
    print("Number is divisible by sum of its digit")
else:
    print("Number is not divisible by sum of its digit")
# Out:
# Number is not divisible by sum of its digit

# %%
#Check if a given number is a perfect cube.

n = int(input())
cube_root = int(n **(1/3))

if cube_root**3 == n:
    print("perfect cube ")
else:
    print("not perfect cube")
# Out:
# perfect cube

# %%
#Check if a given number is a prime number and less than 100.

x = int(input("Enter value: "))

if x <= 1:
    print("not prime")
else:
    for i in range(2,int(x**0.5)+1):
        if x % i == 0:
            print("not prime")
            break
    else :
        if  x<100:
            print("is prime and less than 100")
        else:
            print("is prime and greater than 100")
# Out:
# is prime and greater than 100

# %%
#22. Check if a given number is a Fibonacci number.

# %%
#28. Check if a given list is sorted in descending order. 

l = [7,6,5,4,3,2,1]
r = sorted(l)

if r[::-1] == l:
    print('sorted in descending')
else:
    print('not sorted in desending')
# Out:
# sorted in descending

# %%
#21. Check if a given string is a palindrome ignoring spaces.
n = input()
# Out:
# k
# j
# b
# i
# e

# %%
#33. Check if a given list contains duplicate elements. 
l = [1,2,3]
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]==l[j]:
            print('contains duplicates')
            break
        else :
            print('no duplicates')
            break
# Out:
# no duplicates
# no duplicates

# %%
#38. Check if a given number is a perfect number. 

n = int(input())
total = 0
if n >0:
    for i in range(1,n):
        if n % i ==0:
            total+=i

    if total == n:
        print('perfect number')
    else:
        print('Not perfect')
# Out:
# Not perfect

# %%
num = 986
temp  = num
sum = 0
while temp >  0 :
    sum += temp %10
    temp = temp // 10
print(sum)
if num % sum ==0:
    print('is divisible')
else :
    print('not divisible')
# Out:
# 23
# not divisible

# %%
no = input()
if len(no) == 10 and no.isnumeric()==True:
    print('valid ',no)
else:
    print('invalid ',no)
# Out:
# invalid  9649bjsb

# %%
total = 0
for i in range(1,1000):
    for j in range(1,i):
        if i %j == 0:
            total +=j
        if total == i:
            print(i)
