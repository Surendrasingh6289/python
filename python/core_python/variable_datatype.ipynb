# %%
print("Hello AI Engineer")
# Out:
# Hello AI Engineer

# %%
"Marker"
# Out:
# 'Marker'

# %%
678
# Out:
# 678

# %%
2233/66
# Out:
# 33.833333333333336

# %%
u = "mobile"
print(u)
# Out:
# mobile

# %%
u= "computer"
u
# Out:
# 'computer'

# %%
u = "super computer"
u
# Out:
# 'super computer'

# %%
print(type(u))
# Out:
# <class 'str'>

# %%
a = 456.
print(a)
print(type(a))
# Out:
# 456.0
# <class 'float'>

# %%
j = 45 + 67j
print(j)
print(type(j))
# Out:
# (45+67j)
# <class 'complex'>

# %%
a = 34
b=45
c = 78
a*b+c
# Out:
# 1608

# %%
i = 10
j = 16

mean = (i + j)/2
mean
# Out:
# 13.0

# %%
i = 10
j = 16

mean = i+j/2
mean
# Out:
# 18.0

# %%
v1 = "python"
v1
# Out:
# 'python'

# %%
1v = "c#"
1v
# Out:
#   Cell In[26], line 1
#     1v = "c#"
#     ^
# SyntaxError: invalid decimal literal

# %%
MyName= "Guido Von Rossum"
print(MyName)
# Out:
# Guido Von Rossum
